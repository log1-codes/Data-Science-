# %% [markdown]
# ## WEEK 12

# %% [markdown]
# #### The Normal Equation

# %% [markdown]
# ##### Direct Computing to get the best parameters

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# #### let's create synthetic dataset

# %%
np.random.seed(42)
m = 100 #total instances
X= 2*np.random.rand(m,1) #column vector
y = 4+3*X+np.random.randn(m,1)

# %%
X[:10], y[:10]
plt.plot(X,y,"b.")

# %%
from sklearn.preprocessing import add_dummy_feature
X_b = add_dummy_feature(X) # add x0 =1 to each instance
theta_best = np.linalg.inv(X_b.T @X_b) @ X_b.T@y

# %%
theta_best
# Out:
# array([[4.21509616],
#        [2.77011339]])

# %%
# now predict the value of unseen data
test_data = np.array([[0] ,[2]])
#add bias
test_data_b = add_dummy_feature(test_data) #add x0 =1 To each instance
y_predict = test_data_b @ theta_best
y_predict
# Out:
# array([[4.21509616],
#        [9.75532293]])

# %%
test_data
# Out:
# array([[0],
#        [2]])

# %%
# see on plot 
plt.plot(X,y ,"b.")
plt.plot(test_data , y_predict , "ro")
plt.plot(test_data , y_predict , "g--")

# %% [markdown]
# ## Learning Gradient Descent

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
m = 100 #dataset length
X = 2* np.random.rand(m,1) #column vector
y = 4+3 * X + np.random.randn(m,1) # column vector

# %%
X_b = add_dummy_feature(X)

# %%
eta = 0.1 #learning rate 
n_epochs = 1000
m = len(X_b) #number of instances 

np.random.seed(42) 
theta = np.random.randn(2,1) # weights randomly initialized 

for epoch in range (n_epochs):
    gradients = 2/ m*X_b.T@(X_b@theta -y)
    theta = theta - eta*gradients

theta
# Out:
# array([[4.21509616],
#        [2.77011339]])

# %%
import matplotlib as mpl
from sklearn.matrics import mean_squared_error 
X_new = np.array([[0] ,[2]])
X_new_b = add_dummy_feature(X_new) 
def plot_gradient_descent(theta , eta):
    m = len(X_b)
    plt.plot(X, y ,"b.")
    n_epochs = 1000 
    n_shown = 20 
    theta_path = []
    loss= []
    for epoch in range(n_epochs):
        if epoch < n_shown:
            y_predict = X_new_b @theta 
            plt.plot (X_new , y_predict)
        gradients = 2/m*X_b.T@(X_b @theta -y)
        theta = theta -eta*gradients 
        loss.append((1/m)*np.sum((X_b @theta - y)**2))
        theta_path.append(theta)
    plt.xlabel("$x_1$")
    plt.axis([0,2,0,15])
    plt.grid()
    plt.title(fr"$\eta = {eta}$")
    return theta_path , loss

np.random.seed(42)
theta = np.random.randn(2,1)
theta_path_bgd , loss
