# %% [markdown]
# ## Let's create a function(with docstring)

# %%
def is_even(num):
    """
    this function is made to check that is the number provided is even or not
    input -- any valid integer
    output -- odd/even
    created 0n -- 23 April 2025 
    """
    if(type(num) == int):
        if num%2==0:
            print('even')
        else:
            print('odd')
    else:
        return 'pagal hai kya'
    
is_even('anruag') # calling function
# Out:
# 'pagal hai kya'

# %%
## fetching documentation of any function
print(is_even.__doc__)
# Out:
#     this function is made to check that is the number provided is even or not
#     input -- any valid integer
#     output -- odd/even
#     created 0n -- 23 April 2025

# %%
# function
# function_name(input)
for i in range(1,11):
    x= is_even(i)
    print(x)
# Out:
# odd
# even
# odd
# even
# odd
# even
# odd
# even
# odd
# even

# %% [markdown]
# ## 2 Point of views

# %%
# 1.creating function --> senior programmer
# 2.using fuction --> junior programmer

# %% [markdown]
# ## Parameter Vs Arguments

# %%
# done

# %% [markdown]
# ## Types of arguments

# %% [markdown]
# ##### Default Argument
# ##### Positional Argument
# ##### keyword Argument

# %%
def power(a =1,b=1):
    return a**b

# %%
# power(2)
# power() --> cause of default argument values
# power(2,3)
# Out:
# 1

# %%
# positional argument
power(2,3)   # the order in which arguments are sent in the function parameter recieves in the same order that is known as positional argument
# Out:
# 8

# %%
#keyword argument 
power(b =3 , a =2)  # positions are diff but still arguments recieved correctly
# Out:
# 8

# %% [markdown]
# ### * args and **kwargs

# %% [markdown]
# ##### *args and **kwargs are special python keywords that are used to pass the variable length of arguments to a function

# %%
# *args
# allows us to pass a variable number of non-keyword arguments to a function.
def multiply(*args):
    # print(args) --> tuple of all arguments
    product =1 
    for i in args:
        product = product*i
    return product
multiply(2,3,4,4,5,3,2,2,4,2,4,54,2)
# Out:
# 19906560

# %%
# **kwargs
# **kwargs allows us to pass any number of keyword arguments.
# Keyword arguments mean that they contain a key-value pair, like a Python dictionary.
def display(**kwargs):
    for (key, value) in kwargs.items():
        print(key ,'-->' , value)
display(india ='dehli' , srilanka ='colmbo' , nepal ='kathmandu')
# Out:
# india --> dehli
# srilanka --> colmbo
# nepal --> kathmandu

# %% [markdown]
# ## How functions are executed in memory

# %% [markdown]
# ## Without Return statement

# %%
# --> python still returns a value that is none
L= [1,2,3]
print(L.append(4)) # none because it does not return anything
print(L)
# Out:
# None
# [1, 2, 3, 4]

# %% [markdown]
# ## Variable Scope

# %%
def g(y):
    print(x)
    print(x+1)
x = 5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
def f(y):
    x = 1
    x += 1
    print(x)
x = 5
f(x)
print(x)
# Out:
# 2
# 5

# %%
def h(y):
    x += 1
x = 5
h(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[47], line 4
#       2     x += 1
#       3 x = 5
# ----> 4 h(x)
#       5 print(x)
#
# Cell In[47], line 2, in h(y)
#       1 def h(y):
# ----> 2     x += 1
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
def f(x):
   x = x + 1
   print('in f(x): x =', x)
   return x
x = 3
z = f(x)
print('in main program scope: z =', z)
print('in main program scope: x =', x)
# Out:
# in f(x): x = 4
# in main program scope: z = 4
# in main program scope: x = 3

# %% [markdown]
# ## Nested Functions

# %%
def f():
  def g():
    print('inside function g')
    f()
  g()
  print('inside function f')

# %%
f()
# Out:
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# inside function g
# ...

# %%
def g(x):
    def h():
        x = 'abc'
    x = x + 1
    print('in g(x): x =', x)
    h()
    return x
x = 3
z = g(x)
# Out:
# in g(x): x = 4

# %%
def g(x):
    def h(x):
        x = x+1
        print("in h(x): x = ", x)
    x = x + 1
    print('in g(x): x = ', x)
    h(x)
    return x

x = 3
z = g(x)
print('in main program scope: x = ', x)
print('in main program scope: z = ', z)
# Out:
# in g(x): x =  4
# in h(x): x =  5
# in main program scope: x =  3
# in main program scope: z =  4

# %% [markdown]
# ## Functions are 1st class citizen

# %%
#type and id
def square(num):
    return num**2 

type(square) ## function 
a=2 
type(a)
id(a)
id(square)
# Out:
# 2762696953184

# %%
# reassign
x=  square 
x
id(x)
x(3)
# Out:
# 9

# %%
# deleting a function
del square
sqaure(3) # deleted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 # deleting a function
# ----> 2 del square
#       3 sqaure(3)
#
# NameError: name 'square' is not defined

# %%
#storing 
L = [1,2,3,4,square]

# %%
print(L)
print(L[-1](3))
# Out:
# [1, 2, 3, 4, <function square at 0x000002833D920D60>]
# 9

# %%
s= {square}
s
# Out:
# {<function __main__.square(num)>}

# %%
# returning a function

# %%
def f():
    def x(a, b):
        return a+b
    return x
    
val = f()(3,4)
print(val)
# Out:
# 7

# %%
# function as argument

# %%
def func_a():
    print('inside func_a')

def func_b(z):
    print('inside func_b')
    return z()
print(func_b(func_a))
# Out:
# inside func_b
# inside func_a
# None

# %% [markdown]
# ### Benefits of using function

# %% [markdown]
# ## lambda Functions

# %%
# these functions don't have their names

# %%
# x--> x^2
a = lambda x:x**2
a(2)
# Out:
# 4

# %%
a = lambda x,y : x+y 
a(3,2)
# Out:
# 5

# %%
# check if a string has 'a'
a = lambda s:'a' in s 
a('hello')
# Out:
# False

# %%
#odd or even
a = lambda x : 'even' if x %2 ==0  else 'odd'
a(5) #odd
a(6)
# Out:
# 'even'

# %% [markdown]
# ## Higher Order Functions

# %%
# example
def sqaure(x):
    return x**2 
def cube(x):
    return x**3
def transform(f , L): # it is a higher order function
    output = [] 
    for i in L:
        output.append(f(i))

    print(output)
L=[1,2,3,4,5]
transform(lambda x: x**3 ,L)
transform(lambda x: x**2 ,L)
# Out:
# [1, 8, 27, 64, 125]
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Map

# %%
# square the items of a list 
list(map(lambda x: x**2 , [1,2,3,4,5]))
# Out:
# [1, 4, 9, 16, 25]

# %%
# odd/even labelling of list items
L = [1,2,3,4,5]
list(map(lambda x:'even' if x%2 == 0 else 'odd',L))
# Out:
# ['odd', 'even', 'odd', 'even', 'odd']

# %%
# fetch names from a list of dict

users = [
    {
        'name':'Rahul',
        'age':45,
        'gender':'male'
    },
    {
        'name':'Nitish',
        'age':33,
        'gender':'male'
    },
    {
        'name':'Ankita',
        'age':50,
        'gender':'female'
    }
]

list(map(lambda users:users['gender'],users))
# Out:
# ['male', 'male', 'female']

# %% [markdown]
# ## Filter

# %%
# numbers greater than 5
L = [3,4,5,6,7]

list(filter(lambda x:x>5,L))
# Out:
# [6, 7]

# %%
# fetch fruits starting with 'a'
fruits = ['apple','guava','cherry']

list(filter(lambda x:x.startswith('a'),fruits))
# Out:
# ['apple']

# %% [markdown]
# ## Reduce

# %%
# sum of all item
import functools

functools.reduce(lambda x,y:x+y,[1,2,3,4,5])
# Out:
# 15

# %%
# find min
functools.reduce(lambda x,y:x if x>y else y,[23,11,45,10,1])
# Out:
# 45
